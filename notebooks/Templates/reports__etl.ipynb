# %% [markdown]
# <h1> 📘 Biofilter — Reports to ETL Management </h1>
#
# Biofilter provides a set of built-in ETL reports designed to help users monitor, inspect, and debug data ingestion pipelines. These reports expose the execution status, history, and metadata of ETL processes in a structured and reproducible way, making it easier to understand what has been loaded, what is currently running, and where failures may have occurred.
#
# Methods
#
# * report.run() — Execute a report and return the results as a pandas DataFrame.
#
# Available Reports
#
# * etl_status — High-level, consolidated view of ETL pipelines, showing the latest successful execution per data source and overall pipeline health.
#
# * etl_packages — Detailed, row-level view of all ETL packages, exposing extract, transform, and load steps, timestamps, statuses, and logs for debugging and auditing.

# %% [markdown]
# --------

# %% [markdown]
# ### Start Biofilter3R

# %%
from biofilter import Biofilter
bf = Biofilter()
# Out:
# [INFO] ════════════════════════════════════
# [INFO] 🚀 Initializing Biofilter3R
# [INFO]    • Version: 3.2.0
# [INFO]    • Debug mode: False
# [INFO]    • Config: /home/bioadmin/biofilter/.biofilter.toml
# [INFO] ════════════════════════════════════
# [INFO] 🔌 Database connection established
# [INFO]    • Engine: postgresql+psycopg2
# [INFO]    • Host:   localhost
# [INFO]    • DB:     biofilter
# [INFO]    • Time:   1.4 ms
# [INFO] ════════════════════════════════════

# %% [markdown]
# ------

# %% [markdown]
# ### 1. Report to extract ETL Status in the Database
#
# Returns a consolidated ETL status view per data source, showing the latest successful pipeline state (Extract → Transform → Load) for each selected data source.
#
# This report is designed to answer the question:
#
# * For these data sources, do we have a valid and up-to-date ETL pipeline?

# %%
bf.report.explain("etl_status")
# Out:
# 📦 ETL Status (Latest Good)
#
# This report summarizes ETL execution health per DataSource by selecting:
# - The most recent GOOD extract package (completed or up-to-date)
# - The most recent GOOD transform package
# - The most recent GOOD load package
#
# If the latest extract is newer but transform/load are missing or not aligned
# (by hash), the report still shows the last good transform/load and flags them
# as stale (not aligned with latest extract).

# %%
# df = bf.report.run("report_etl_status")
df = bf.report.run(
    "etl_status",
    source_system="ncbi",
    data_sources=["dbsnp_chr6",],
)
df
# Out:
#    source_system             data_source              data_type  pipeline_ok  \
# 40       BioGRID                 biogrid          relationships         True
# 38       CLINGEN                 clingen  disease relationships         True
# 36           EBI                   chebi               chemical         True
# 37           EBI                    gwas                variant         True
# 31           EBI                    pfam                Protein         True
# 2        Ensembl                 ensembl                   Gene         True
# 32            GO           gene_ontology                     go         True
# 1           HGNC                    hgnc                   Gene         True
# 33          KEGG           kegg_pathways                pathway         True
# 34         MONDO                   mondo                disease         True
# 35         MONDO     mondo_relationships                disease        False
# 3           NCBI              dbsnp_chr1                Variant         True
# 12          NCBI             dbsnp_chr10                Variant         True
# 13          NCBI             dbsnp_chr11                Variant         True
# 14          NCBI             dbsnp_chr12                Variant         True
# 15          NCBI             dbsnp_chr13                Variant         True
# 16          NCBI             dbsnp_chr14                Variant         True
# 17          NCBI             dbsnp_chr15                Variant         True
# 18          NCBI             dbsnp_chr16                Variant         True
# 19          NCBI             dbsnp_chr17                Variant         True
# 20          NCBI             dbsnp_chr18                Variant         True
# 21          NCBI             dbsnp_chr19                Variant         True
# 4           NCBI              dbsnp_chr2                Variant         True
# 22          NCBI             dbsnp_chr20                Variant         True
# 23          NCBI             dbsnp_chr21                Variant         True
# 24          NCBI             dbsnp_chr22                Variant         True
# 5           NCBI              dbsnp_chr3                Variant         True
# 6           NCBI              dbsnp_chr4                Variant         True
# 7           NCBI              dbsnp_chr5                Variant         True
# 8           NCBI              dbsnp_chr6                Variant         True
# 9           NCBI              dbsnp_chr7                Variant         True
# 10          NCBI              dbsnp_chr8                Variant         True
# 11          NCBI              dbsnp_chr9                Variant         True
# 25          NCBI              dbsnp_chrx                Variant         True
# 26          NCBI              dbsnp_chry                Variant         True
# 0           NCBI               gene_ncbi                   Gene         True
# 39          OMIM                    omim  disease relationships        False
# 27      Reactome                reactome                Pathway         True
# 28      Reactome  reactome_relationships                Pathway        False
# 29       UniProt                 uniprot                Protein         True
# 30       UniProt   uniprot_relationships                Protein        False
#
#     extract_package_id extract_status                extract_end  \
# 40                75.0      completed 2025-12-13 09:25:34.315252
# 38                28.0      completed 2025-12-12 00:19:15.750868
# 36                34.0      completed 2025-12-12 01:02:10.878113
# 37                55.0      completed 2025-12-12 16:32:39.943378
# 31                10.0      completed 2025-12-11 22:21:33.087696
# 2                102.0      completed 2025-12-15 22:14:46.257485
# 32                19.0      completed 2025-12-11 23:23:59.595218
# 1                  4.0      completed 2025-12-11 20:21:25.089539
# 33                41.0      completed 2025-12-12 01:10:19.001906
# 34                22.0      completed 2025-12-11 23:25:19.103821
# 35                78.0      completed 2025-12-13 09:47:42.913973
# 3                 40.0      completed 2025-12-12 02:48:36.670498
# 12                96.0      completed 2025-12-15 15:41:31.689639
# 13               123.0      completed 2025-12-17 18:38:47.902210
# 14               124.0      completed 2025-12-17 18:43:26.612570
# 15               125.0      completed 2025-12-17 18:27:09.941362
# 16               130.0      completed 2025-12-18 04:23:09.667025
# 17               131.0      completed 2025-12-18 04:18:04.609544
# 18               132.0      completed 2025-12-18 04:25:27.347439
# 19               115.0      completed 2025-12-17 00:07:03.174312
# 20               133.0      completed 2025-12-18 04:10:56.636660
# 21               116.0      completed 2025-12-17 00:01:09.754403
# 4                 45.0      completed 2025-12-12 05:50:29.425576
# 22               143.0      completed 2025-12-18 17:04:12.928628
# 23               144.0      completed 2025-12-18 16:50:03.326081
# 24               145.0      completed 2025-12-18 16:53:04.922743
# 5                 51.0      completed 2025-12-12 16:05:40.061625
# 6                 52.0      completed 2025-12-12 15:38:43.764534
# 7                 83.0      completed 2025-12-14 00:20:00.785427
# 8                 84.0      completed 2025-12-14 00:16:48.905348
# 9                 87.0      completed 2025-12-14 04:15:39.604069
# 10                88.0      completed 2025-12-14 03:58:34.150768
# 11                95.0      completed 2025-12-15 15:46:22.065779
# 25               146.0      completed 2025-12-18 17:18:56.667795
# 26                 1.0      completed 2025-12-11 18:53:11.877289
# 0                  7.0      completed 2025-12-11 21:52:01.717254
# 39                 NaN           None                        NaT
# 27                37.0      completed 2025-12-12 01:03:00.983269
# 28                67.0      completed 2025-12-13 01:19:38.418232
# 29                13.0      completed 2025-12-11 22:32:47.382133
# 30                71.0      completed 2025-12-13 03:07:38.595335
#
#     transform_package_id transform_status              transform_end  \
# 40                  76.0        completed 2025-12-13 09:30:43.255111
# 38                  29.0        completed 2025-12-12 00:19:17.095260
# 36                  35.0        completed 2025-12-12 01:02:33.543827
# 37                  56.0        completed 2025-12-12 16:35:00.898027
# 31                  11.0        completed 2025-12-11 22:21:34.648981
# 2                  100.0        completed 2025-12-15 21:46:17.228638
# 32                  20.0        completed 2025-12-11 23:24:03.099797
# 1                    5.0        completed 2025-12-11 20:21:30.962815
# 33                  42.0        completed 2025-12-12 01:10:19.127686
# 34                  23.0        completed 2025-12-11 23:25:26.361527
# 35                  79.0        completed 2025-12-13 09:47:42.950443
# 3                   44.0        completed 2025-12-13 02:06:20.737723
# 12                  97.0        completed 2025-12-16 06:08:26.608209
# 13                 127.0        completed 2025-12-18 04:57:33.449906
# 14                 128.0        completed 2025-12-17 18:43:26.748967
# 15                 126.0        completed 2025-12-18 00:51:46.010492
# 16                 136.0        completed 2025-12-18 11:04:01.120544
# 17                 135.0        completed 2025-12-18 10:51:22.541236
# 18                 137.0        completed 2025-12-18 11:30:44.355219
# 19                 118.0        completed 2025-12-17 06:47:36.659932
# 20                 134.0        completed 2025-12-18 09:46:35.403368
# 21                 117.0        completed 2025-12-17 05:07:49.793916
# 4                   46.0        completed 2025-12-13 05:24:50.411411
# 22                 150.0        completed 2025-12-18 21:25:57.786551
# 23                 148.0        completed 2025-12-18 19:25:05.622679
# 24                 149.0        completed 2025-12-18 19:54:54.719857
# 5                   54.0        completed 2025-12-13 12:14:05.595749
# 6                   53.0        completed 2025-12-13 09:28:29.744992
# 7                   86.0        completed 2025-12-14 20:22:00.429866
# 8                   85.0        completed 2025-12-14 20:38:19.047399
# 9                   90.0        completed 2025-12-14 22:58:12.906719
# 10                  89.0        completed 2025-12-14 21:42:07.732675
# 11                  98.0        completed 2025-12-16 05:20:50.169835
# 25                 151.0        completed 2025-12-19 00:29:30.088616
# 26                   2.0        completed 2025-12-11 19:51:37.109175
# 0                    8.0        completed 2025-12-11 21:58:21.200316
# 39                   NaN             None                        NaT
# 27                  38.0        completed 2025-12-12 01:03:05.849488
# 28                  68.0        completed 2025-12-13 01:19:38.489785
# 29                  14.0        completed 2025-12-11 22:37:01.055285
# 30                  72.0        completed 2025-12-13 03:07:38.642182
#
#     transform_aligned_with_latest_extract  load_package_id load_status  \
# 40                                   True             77.0   completed
# 38                                   True             30.0   completed
# 36                                   True             36.0   completed
# 37                                   True             66.0   completed
# 31                                   True             12.0   completed
# 2                                    True            101.0   completed
# 32                                   True             21.0   completed
# 1                                    True              6.0   completed
# 33                                   True             43.0   completed
# 34                                   True             24.0   completed
# 35                                  False             80.0   completed
# 3                                    True             70.0   completed
# 12                                   True            114.0   completed
# 13                                   True            138.0   completed
# 14                                   True            147.0   completed
# 15                                   True            129.0   completed
# 16                                   True            141.0   completed
# 17                                   True            140.0   completed
# 18                                   True            142.0   completed
# 19                                   True            121.0   completed
# 20                                   True            139.0   completed
# 21                                   True            120.0   completed
# 4                                    True             74.0   completed
# 22                                   True            154.0   completed
# 23                                   True            152.0   completed
# 24                                   True            153.0   completed
# 5                                    True             81.0   completed
# 6                                    True             82.0   completed
# 7                                    True             91.0   completed
# 8                                    True            122.0   completed
# 9                                    True             94.0   completed
# 10                                   True             93.0   completed
# 11                                   True            119.0   completed
# 25                                   True            155.0   completed
# 26                                   True              3.0   completed
# 0                                    True              9.0   completed
# 39                                  False              NaN        None
# 27                                   True             39.0   completed
# 28                                  False             69.0   completed
# 29                                   True             15.0   completed
# 30                                  False             73.0   completed
#
#                      load_end  load_aligned_with_latest_transform  \
# 40 2025-12-13 09:47:42.844820                                True
# 38 2025-12-12 00:19:19.214334                                True
# 36 2025-12-12 04:19:38.034336                                True
# 37 2025-12-12 21:56:12.724327                                True
# 31 2025-12-11 22:23:38.439463                                True
# 2  2025-12-15 22:12:33.201853                                True
# 32 2025-12-12 00:23:47.276362                                True
# 1  2025-12-11 21:46:05.008231                                True
# 33 2025-12-12 01:11:26.468974                                True
# 34 2025-12-12 00:19:06.839070                                True
# 35 2025-12-13 09:56:33.408226                               False
# 3  2025-12-13 16:39:57.230788                                True
# 12 2025-12-16 18:34:53.183406                                True
# 13 2025-12-18 12:32:48.768501                                True
# 14 2025-12-18 23:56:54.472693                                True
# 15 2025-12-18 06:17:22.755933                                True
# 16 2025-12-18 15:58:23.864964                                True
# 17 2025-12-18 15:34:56.501903                                True
# 18 2025-12-18 16:30:52.395534                                True
# 19 2025-12-17 15:01:27.705359                                True
# 20 2025-12-18 14:12:39.361056                                True
# 21 2025-12-17 10:02:06.235874                                True
# 4  2025-12-14 00:27:13.428307                                True
# 22 2025-12-19 01:01:37.416983                                True
# 23 2025-12-18 21:37:36.375137                                True
# 24 2025-12-18 22:12:37.562507                                True
# 5  2025-12-15 07:43:45.721373                                True
# 6  2025-12-15 01:08:00.379724                                True
# 7  2025-12-16 09:36:34.092903                                True
# 8  2025-12-18 02:49:53.276589                                True
# 9  2025-12-16 10:44:42.763483                                True
# 10 2025-12-16 08:10:35.110971                                True
# 11 2025-12-17 08:29:51.937904                                True
# 25 2025-12-19 06:37:40.611090                                True
# 26 2025-12-11 21:10:40.875892                                True
# 0  2025-12-11 23:06:28.423349                                True
# 39                        NaT                               False
# 27 2025-12-12 01:10:16.941811                                True
# 28 2025-12-13 03:07:38.512702                               False
# 29 2025-12-11 23:51:40.991227                                True
# 30 2025-12-13 09:24:53.644612                               False
#
#                                          latest_error
# 40                                               None
# 38                                               None
# 36                                               None
# 37  ❌ Error inserting records: (psycopg2.Programmi...
# 31                                               None
# 2                                                None
# 32                                               None
# 1                                                None
# 33                                               None
# 34                                               None
# 35                                               None
# 3                                                None
# 12                                               None
# 13                                               None
# 14                                               None
# 15                                               None
# 16                                               None
# 17                                               None
# 18                                               None
# 19                                               None
# 20                                               None
# 21                                               None
# 4                                                None
# 22                                               None
# 23                                               None
# 24                                               None
# 5                                                None
# 6                                                None
# 7                                                None
# 8                                                None
# 9                                                None
# 10                                               None
# 11                                               None
# 25                                               None
# 26                                               None
# 0                                                None
# 39                                               None
# 27                                               None
# 28                                               None
# 29                                               None
# 30                                               None

# %% [markdown]
# -------

# %% [markdown]
# ### 2. Report to extract ETL the Packages history
#
# The etl_packages report provides a detailed, row-level view of ETL execution history, returning one row per ETLPackage created in the system. It exposes full metadata for each package, including source system, data source, operation type (extract, transform, load), execution timestamps, per-stage statuses, hashes, row counts, and optional logs or error messages. This report is intended for debugging, auditing, and operational analysis, allowing users to inspect failed, running, skipped, or completed ETL steps, trace pipeline execution order, and understand exactly what happened during each ETL phase. Unlike etl_status, it does not consolidate results and instead reflects the raw ETL lifecycle as recorded in the database.

# %%
bf.report.explain("etl_packages")
# Out:
# 📦 ETL Packages – Detailed Audit Report
# ======================================
#
# This report provides a **raw, non-aggregated** view of the ETL execution state.
#
# Each row corresponds to **one ETLPackage record**, which may represent:
# - one ETL stage (extract / transform / load), or
# - one full execution attempt, depending on how the ETL was triggered.
#
# The report joins:
# - ETLSourceSystem (e.g. NCBI, Ensembl, UniProt)
# - ETLDataSource (e.g. dbSNP_chr1, ensembl, hgnc)
# - ETLPackage (execution metadata)
#
# This report is intentionally *not consolidated*.
# It is designed for:
# - Debugging failed or stuck jobs
# - Auditing execution history
# - Understanding how many packages were created per data source
# - Verifying status transitions across ETL stages
#
# Recommended usage:
# - Use this report to identify inconsistencies
# - Fix ETL status logic
# - Only then create consolidated / dashboard-style reports

# %%
# df = bf.report.run("etl_packages")
df = bf.report.run(
    "etl_packages",
    source_system="ncbi",
    # data_sources=["dbsnp_chr6",],
)
df
# Out:
#     package_id                 created_at source_system  data_source  \
# 0          111 2025-12-16 06:08:26.692916          NCBI  dbsnp_chr10
# 1          110 2025-12-16 05:20:50.371078          NCBI   dbsnp_chr9
# 2           98 2025-12-15 15:46:22.126611          NCBI   dbsnp_chr9
# 3           97 2025-12-15 15:41:31.872640          NCBI  dbsnp_chr10
# 4           96 2025-12-15 14:18:11.257703          NCBI  dbsnp_chr10
# 5           95 2025-12-15 14:17:58.342017          NCBI   dbsnp_chr9
# 6           94 2025-12-14 22:58:12.935550          NCBI   dbsnp_chr7
# 7           93 2025-12-14 21:42:07.757679          NCBI   dbsnp_chr8
# 8           92 2025-12-14 20:38:19.081557          NCBI   dbsnp_chr6
# 9           91 2025-12-14 20:22:00.497338          NCBI   dbsnp_chr5
# 10          90 2025-12-14 04:15:39.725309          NCBI   dbsnp_chr7
# 11          89 2025-12-14 03:58:34.456954          NCBI   dbsnp_chr8
# 12          88 2025-12-14 02:00:07.731044          NCBI   dbsnp_chr8
# 13          87 2025-12-14 01:59:53.901995          NCBI   dbsnp_chr7
# 14          86 2025-12-14 00:20:00.847546          NCBI   dbsnp_chr5
# 15          85 2025-12-14 00:16:48.973588          NCBI   dbsnp_chr6
# 16          84 2025-12-13 22:53:41.950126          NCBI   dbsnp_chr6
# 17          83 2025-12-13 22:53:24.686327          NCBI   dbsnp_chr5
# 18          82 2025-12-13 22:53:04.373134          NCBI   dbsnp_chr4
# 19          81 2025-12-13 22:52:29.245646          NCBI   dbsnp_chr3
# 20          74 2025-12-13 05:24:50.455234          NCBI   dbsnp_chr2
# 21          70 2025-12-13 02:06:20.759949          NCBI   dbsnp_chr1
# 22          54 2025-12-12 16:05:40.142367          NCBI   dbsnp_chr3
# 23          53 2025-12-12 15:38:43.825942          NCBI   dbsnp_chr4
# 24          52 2025-12-12 14:11:37.147967          NCBI   dbsnp_chr4
# 25          51 2025-12-12 14:11:22.526731          NCBI   dbsnp_chr3
# 26          47 2025-12-12 13:58:34.257526          NCBI   dbsnp_chr2
# 27          46 2025-12-12 05:50:29.474378          NCBI   dbsnp_chr2
# 28          45 2025-12-12 03:51:01.369143          NCBI   dbsnp_chr2
# 29          44 2025-12-12 02:48:36.734476          NCBI   dbsnp_chr1
# 30          40 2025-12-12 01:03:26.827303          NCBI   dbsnp_chr1
# 31           9 2025-12-11 21:58:21.237520          NCBI    gene_ncbi
# 32           8 2025-12-11 21:52:01.775560          NCBI    gene_ncbi
# 33           7 2025-12-11 21:46:05.060973          NCBI    gene_ncbi
# 34           3 2025-12-11 19:51:37.257568          NCBI   dbsnp_chry
# 35           2 2025-12-11 18:53:11.913843          NCBI   dbsnp_chry
# 36           1 2025-12-11 18:51:18.425782          NCBI   dbsnp_chry
#
#        status operation_type version_tag  note  \
# 0     running        running        None  None
# 1     running        running        None  None
# 2      failed      transform        None  None
# 3      failed      transform        None  None
# 4   completed        extract        None  None
# 5   completed        extract        None  None
# 6   completed           load        None  None
# 7   completed           load        None  None
# 8      failed           load        None  None
# 9   completed           load        None  None
# 10  completed      transform        None  None
# 11  completed      transform        None  None
# 12  completed        extract        None  None
# 13  completed        extract        None  None
# 14  completed      transform        None  None
# 15  completed      transform        None  None
# 16  completed        extract        None  None
# 17  completed        extract        None  None
# 18  completed           load        None  None
# 19  completed           load        None  None
# 20  completed           load        None  None
# 21  completed           load        None  None
# 22  completed      transform        None  None
# 23  completed      transform        None  None
# 24  completed        extract        None  None
# 25  completed        extract        None  None
# 26     failed        extract        None  None
# 27  completed      transform        None  None
# 28  completed        extract        None  None
# 29  completed      transform        None  None
# 30  completed        extract        None  None
# 31  completed           load        None  None
# 32  completed      transform        None  None
# 33  completed        extract        None  None
# 34  completed           load        None  None
# 35  completed      transform        None  None
# 36  completed        extract        None  None
#
#                                                   log  extract_status  ...  \
# 0   {"note": "load skipped", "reason": "no transfo...         pending  ...
# 1   {"note": "load skipped", "reason": "no transfo...         pending  ...
# 2                                                None  not-applicable  ...
# 3                                                None  not-applicable  ...
# 4                                                None       completed  ...
# 5                                                None       completed  ...
# 6                                                None  not-applicable  ...
# 7                                                None  not-applicable  ...
# 8                                                None  not-applicable  ...
# 9                                                None  not-applicable  ...
# 10                                               None         pending  ...
# 11                                               None         pending  ...
# 12                                               None       completed  ...
# 13                                               None       completed  ...
# 14                                               None         pending  ...
# 15                                               None         pending  ...
# 16                                               None       completed  ...
# 17                                               None       completed  ...
# 18                                               None         pending  ...
# 19                                               None         pending  ...
# 20                                               None         pending  ...
# 21                                               None         pending  ...
# 22                                               None         pending  ...
# 23                                               None         pending  ...
# 24                                               None       completed  ...
# 25                                               None       completed  ...
# 26                                               None  not-applicable  ...
# 27                                               None         pending  ...
# 28                                               None       completed  ...
# 29                                               None         pending  ...
# 30                                               None       completed  ...
# 31                                               None         pending  ...
# 32                                               None         pending  ...
# 33                                               None       completed  ...
# 34                                               None         pending  ...
# 35                                               None         pending  ...
# 36                                               None       completed  ...
#
#    transform_rows                                     transform_hash  \
# 0            None                                               None
# 1            None                                               None
# 2            None                   981dcd9b31538d6f5af5701bd5c60dfe
# 3            None                   6d996161d665e139d0c72041ae825ce7
# 4            None                                               None
# 5            None                                               None
# 6            None                                               None
# 7            None                                               None
# 8            None                                               None
# 9            None                                               None
# 10           None                   e3185931e6159b31bdf3f50f55973ff3
# 11           None                   2ce6dd8b7b4c844d90ec917eb2743fed
# 12           None                                               None
# 13           None                                               None
# 14           None                   f7082da928d66bf24c3694a48213add4
# 15           None                   2b656149c86f27edd02ec231fbbf0cb4
# 16           None                                               None
# 17           None                                               None
# 18           None                                               None
# 19           None                                               None
# 20           None                                               None
# 21           None                                               None
# 22           None                   dbf879c425df6109480e4833ee36089e
# 23           None                   2096a2fab47a899d633eb35d4b11c8e5
# 24           None                                               None
# 25           None                                               None
# 26           None                                               None
# 27           None                   0ec7a9c832450819984ebbd43ca5fcd1
# 28           None                                               None
# 29           None                   cbddf8bbb56e1a8ee106c320fce7468b
# 30           None                                               None
# 31           None                                               None
# 32           None  fb309759211a567afb652e044824211ebd7eb1e9c04e75...
# 33           None                                               None
# 34           None                                               None
# 35           None                   2543d126a85a659797406f835d7589b1
# 36           None                                               None
#
#        load_status                 load_start                   load_end  \
# 0   not-applicable 2025-12-16 06:08:26.743429 2025-12-16 06:08:26.743487
# 1   not-applicable 2025-12-16 05:20:50.431777 2025-12-16 05:20:50.431832
# 2   not-applicable                        NaT                        NaT
# 3   not-applicable                        NaT                        NaT
# 4          pending                        NaT                        NaT
# 5          pending                        NaT                        NaT
# 6        completed 2025-12-14 22:58:12.987173 2025-12-16 10:44:42.763483
# 7        completed 2025-12-14 21:42:07.782899 2025-12-16 08:10:35.110971
# 8   not-applicable 2025-12-14 20:38:19.119724                        NaT
# 9        completed 2025-12-14 20:22:00.533792 2025-12-16 09:36:34.092903
# 10         pending                        NaT                        NaT
# 11         pending                        NaT                        NaT
# 12         pending                        NaT                        NaT
# 13         pending                        NaT                        NaT
# 14         pending                        NaT                        NaT
# 15         pending                        NaT                        NaT
# 16         pending                        NaT                        NaT
# 17         pending                        NaT                        NaT
# 18       completed 2025-12-13 22:53:04.799153 2025-12-15 01:08:00.379724
# 19       completed 2025-12-13 22:52:29.903926 2025-12-15 07:43:45.721373
# 20       completed 2025-12-13 05:24:50.477270 2025-12-14 00:27:13.428307
# 21       completed 2025-12-13 02:06:20.776466 2025-12-13 16:39:57.230788
# 22         pending                        NaT                        NaT
# 23         pending                        NaT                        NaT
# 24         pending                        NaT                        NaT
# 25         pending                        NaT                        NaT
# 26  not-applicable                        NaT                        NaT
# 27         pending                        NaT                        NaT
# 28         pending                        NaT                        NaT
# 29         pending                        NaT                        NaT
# 30         pending                        NaT                        NaT
# 31       completed 2025-12-11 21:58:21.269572 2025-12-11 23:06:28.423349
# 32         pending                        NaT                        NaT
# 33         pending                        NaT                        NaT
# 34       completed 2025-12-11 19:51:37.326492 2025-12-11 21:10:40.875892
# 35         pending                        NaT                        NaT
# 36         pending                        NaT                        NaT
#
#    load_rows                                          load_hash  \
# 0       None                                               None
# 1       None                                               None
# 2       None                                               None
# 3       None                                               None
# 4       None                                               None
# 5       None                                               None
# 6       None                   e3185931e6159b31bdf3f50f55973ff3
# 7       None                   2ce6dd8b7b4c844d90ec917eb2743fed
# 8       None                   2b656149c86f27edd02ec231fbbf0cb4
# 9       None                   f7082da928d66bf24c3694a48213add4
# 10      None                                               None
# 11      None                                               None
# 12      None                                               None
# 13      None                                               None
# 14      None                                               None
# 15      None                                               None
# 16      None                                               None
# 17      None                                               None
# 18      None                   2096a2fab47a899d633eb35d4b11c8e5
# 19      None                   dbf879c425df6109480e4833ee36089e
# 20      None                   0ec7a9c832450819984ebbd43ca5fcd1
# 21      None                   cbddf8bbb56e1a8ee106c320fce7468b
# 22      None                                               None
# 23      None                                               None
# 24      None                                               None
# 25      None                                               None
# 26      None                                               None
# 27      None                                               None
# 28      None                                               None
# 29      None                                               None
# 30      None                                               None
# 31      None  fb309759211a567afb652e044824211ebd7eb1e9c04e75...
# 32      None                                               None
# 33      None                                               None
# 34      None                   2543d126a85a659797406f835d7589b1
# 35      None                                               None
# 36      None                                               None
#
#    extract_minutes transform_minutes  load_minutes
# 0              NaN               NaN  9.666667e-07
# 1              NaN               NaN  9.166667e-07
# 2              NaN        814.465810           NaN
# 3              NaN        866.909423           NaN
# 4        83.334922               NaN           NaN
# 5        88.386621               NaN           NaN
# 6              NaN               NaN  2.146496e+03
# 7              NaN               NaN  2.068455e+03
# 8              NaN               NaN           NaN
# 9              NaN               NaN  2.234559e+03
# 10             NaN       1122.547534           NaN
# 11             NaN       1063.550986           NaN
# 12      118.433704               NaN           NaN
# 13      135.745742               NaN           NaN
# 14             NaN       1201.992259           NaN
# 15             NaN       1221.499480           NaN
# 16       83.111548               NaN           NaN
# 17       86.598057               NaN           NaN
# 18             NaN               NaN  1.574926e+03
# 19             NaN               NaN  1.971264e+03
# 20             NaN               NaN  1.142383e+03
# 21             NaN               NaN  8.736076e+02
# 22             NaN       1208.423457           NaN
# 23             NaN       1069.764500           NaN
# 24       87.105916               NaN           NaN
# 25      114.286693               NaN           NaN
# 26             NaN               NaN           NaN
# 27             NaN       1414.347863           NaN
# 28      119.458584               NaN           NaN
# 29             NaN       1397.732143           NaN
# 30      105.159639               NaN           NaN
# 31             NaN               NaN  6.811923e+01
# 32             NaN          6.323102           NaN
# 33        5.942058               NaN           NaN
# 34             NaN               NaN  7.905916e+01
# 35             NaN         58.419469           NaN
# 36        1.878683               NaN           NaN
#
# [37 rows x 27 columns]
