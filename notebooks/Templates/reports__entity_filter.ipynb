# %% [markdown]
# <h1> 📘 Biofilter — Report: Entity Filter </h1>
#
# Validate a list of entity names and inspect matching/conflict flags.

# %% [markdown]
# ### 1. Start Biofilter

# %%
from biofilter import Biofilter
bf = Biofilter(debug_mode=False)
# Out:
# [INFO] ════════════════════════════════════
# [INFO] 🚀 Initializing Biofilter
# [INFO]    • Version: 4.1.1
# [INFO]    • Debug mode: False
# [INFO]    • Config: /Users/andrerico/Works/Sys/biofilter/.biofilter.toml
# [INFO]    • DB URI: postgresql+psycopg2://admin:***@localhost/biofilter_dev
# [INFO] ════════════════════════════════════
# [INFO] 🔌 Database connection established
# [INFO]    • Engine: postgresql+psycopg2
# [INFO]    • Host:   localhost
# [INFO]    • DB:     biofilter_dev
# [INFO]    • Time:   1.9 ms
# [INFO] ════════════════════════════════════

# %% [markdown]
# ### 2. Run with custom entity list (API parameters required)

# %%
entity_list = ["TP53", "BRCA1", "APOE", "NOT_FOUND_ENTITY"]

df = bf.report.run("entity_filter", input_data=entity_list)
print(f"Rows: {len(df)}")
df.head()
# Out:
# Rows: 4
#      input_original             input is_primary entity_id primary_name  \
# 0              APOE              APOE       True     11447         APOE
# 1             BRCA1             BRCA1       True     22848        BRCA1
# 2              TP53              TP53       True     37287         TP53
# 3  NOT_FOUND_ENTITY  NOT_FOUND_ENTITY       None      None         None
#
#   group_id group_name has_conflict is_active is_deactive data_source_id  \
# 0        2      Genes         None      True       False              2
# 1        2      Genes         None      True       False              2
# 2        2      Genes         None      True       False              2
# 3     None       None         None      None        None           None
#
#   observation
# 0
# 1
# 2
# 3   not found

# %%
cols = [
    "input_original", "primary_name", "group_name",
    "has_conflict", "is_deactive", "observation"
]
df[[c for c in cols if c in df.columns]].head(50)
# Out:
#      input_original primary_name group_name has_conflict is_deactive  \
# 0              APOE         APOE      Genes         None       False
# 1             BRCA1        BRCA1      Genes         None       False
# 2              TP53         TP53      Genes         None       False
# 3  NOT_FOUND_ENTITY         None       None         None        None
#
#   observation
# 0
# 1
# 2
# 3   not found
