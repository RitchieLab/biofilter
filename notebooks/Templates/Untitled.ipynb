# %%
from biofilter import Biofilter
bf = Biofilter()
# Out:
# [INFO] ════════════════════════════════════
# [INFO] 🚀 Initializing Biofilter3R
# [INFO]    • Version: 3.2.0
# [INFO]    • Debug mode: False
# [INFO]    • Config: /home/bioadmin/biofilter/.biofilter.toml
# [INFO] ════════════════════════════════════
# [INFO] 🔌 Database connection established
# [INFO]    • Engine: postgresql+psycopg2
# [INFO]    • Host:   localhost
# [INFO]    • DB:     biofilter
# [INFO]    • Time:   0.9 ms
# [INFO] ════════════════════════════════════

# %%
# List all registered reports with descriptions
bf.report.list_reports()
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[2], line 2
#       1 # List all registered reports with descriptions
# ----> 2 bf.report.list_reports()
#
# File ~/biofilter/biofilter/report/report_manager.py:43, in ReportManager.list_reports(self, verbose)
#      41 for _, name, _ in pkgutil.iter_modules(reports_pkg.__path__):
#      42     if name.startswith("report_"):
# ---> 43         report_class = self._load_report_class(name)
#      44         reports.append(
#      45             {
#      46                 "name": report_class.name,
#      47                 "description": getattr(report_class, "description", ""),
#      48             }
#      49         )
#      50 if verbose:
#
# File ~/biofilter/biofilter/report/report_manager.py:16, in ReportManager._load_report_class(self, name)
#      15 def _load_report_class(self, name: str):
# ...
