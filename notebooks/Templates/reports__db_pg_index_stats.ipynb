# %% [markdown]
# <h1> 📘 Biofilter — Report: PostgreSQL Index Stats </h1>
#
# PostgreSQL-only index observability report (size, properties, usage).

# %% [markdown]
# ### 1. Start Biofilter

# %%
from biofilter import Biofilter
bf = Biofilter(debug_mode=False)
# Out:
# [INFO] ════════════════════════════════════
# [INFO] 🚀 Initializing Biofilter
# [INFO]    • Version: 4.1.1
# [INFO]    • Debug mode: False
# [INFO]    • Config: /Users/andrerico/Works/Sys/biofilter/.biofilter.toml
# [INFO]    • DB URI: postgresql+psycopg2://admin:***@localhost/biofilter_dev
# [INFO] ════════════════════════════════════
# [INFO] 🔌 Database connection established
# [INFO]    • Engine: postgresql+psycopg2
# [INFO]    • Host:   localhost
# [INFO]    • DB:     biofilter_dev
# [INFO]    • Time:   1.9 ms
# [INFO] ════════════════════════════════════

# %% [markdown]
# ### 2. Inspect report metadata

# %%
bf.report.explain("db_pg_index_stats")
# Out:
# '📚 PostgreSQL Index Stats\n\nThis report is PostgreSQL-only and returns one row per index, including:\n- index size (bytes + pretty)\n- access method (btree/gin/gist/brin/...)\n- properties: unique, primary, valid, ready\n- index definition (pg_get_indexdef)\n\nOptional:\n- usage counters from pg_stat_all_indexes: idx_scan, idx_tup_read, idx_tup_fetch\n\nNotes:\n- Usage stats reset when PostgreSQL restarts or when stats are reset.\n- Index size is from pg_relation_size(index_oid).\n'

# %%
bf.report.available_columns("db_pg_index_stats")
# Out:
# ['schema_name',
#  'table_name',
#  'index_name',
#  'index_method',
#  'is_unique',
#  'is_primary',
#  'is_valid',
#  'is_ready',
#  'index_bytes',
#  'index_size',
#  'index_def',
#  'idx_scan',
#  'idx_tup_read',
#  'idx_tup_fetch']

# %% [markdown]
# ### 3. Run report (PostgreSQL only)

# %%
df = bf.report.run("db_pg_index_stats")
print(f"Rows: {len(df)}")
df.head()
# Out:
# Rows: 278
#   schema_name                        table_name  \
# 0      public  variant_molecular_effects_chr_24
# 1      public            variant_masters_chr_24
# 2      public            variant_masters_chr_24
# 3      public                    entity_aliases
# 4      public                    entity_aliases
#
#                                           index_name index_method  is_unique  \
# 0              variant_molecular_effects_chr_24_pkey        btree       True
# 1  variant_masters_chr_24_chromosome_position_sta...        btree       True
# 2                        variant_masters_chr_24_pkey        btree       True
# 3                    uq_entity_names_semantic_unique        btree       True
# 4         idx_entity_aliases_xref_source_alias_value        btree      False
#
#    is_primary  is_valid  is_ready  index_bytes index_size  \
# 0        True      True      True    354811904     338 MB
# 1       False      True      True     49512448      47 MB
# 2        True      True      True     24526848      23 MB
# 3       False      True      True     24363008      23 MB
# 4       False      True      True     17235968      16 MB
#
#                                            index_def  idx_scan  idx_tup_read  \
# 0  CREATE UNIQUE INDEX variant_molecular_effects_...   5063989           282
# 1  CREATE UNIQUE INDEX variant_masters_chr_24_chr...    776847        776858
# 2  CREATE UNIQUE INDEX variant_masters_chr_24_pke...         0             0
# 3  CREATE UNIQUE INDEX uq_entity_names_semantic_u...         1             0
# 4  CREATE INDEX idx_entity_aliases_xref_source_al...         0             0
#
#    idx_tup_fetch
# 0            282
# 1         776858
# 2              0
# 3              0
# 4              0

# %% [markdown]
# ### 4. Filter by table/index and choose columns

# %%
df_filtered = bf.report.run(
    "db_pg_index_stats",
    schema="public",
    table=["variant_masters"],
    include_usage=True,
    output_columns=["schema_name", "table_name", "index_name", "index_size", "idx_scan"],
)
print(f"Rows: {len(df_filtered)}")
df_filtered.head(30)
# Out:
# Rows: 52
#     schema_name              table_name  \
# 1        public  variant_masters_chr_24
# 2        public  variant_masters_chr_24
# 174      public   variant_masters_chr_1
# 175      public   variant_masters_chr_1
# 176      public  variant_masters_chr_10
# 177      public  variant_masters_chr_10
# 178      public  variant_masters_chr_11
# 179      public  variant_masters_chr_11
# 180      public  variant_masters_chr_12
# 181      public  variant_masters_chr_12
# 182      public  variant_masters_chr_13
# 183      public  variant_masters_chr_13
# 184      public  variant_masters_chr_14
# 185      public  variant_masters_chr_14
# 186      public  variant_masters_chr_15
# 187      public  variant_masters_chr_15
# 188      public  variant_masters_chr_16
# 189      public  variant_masters_chr_16
# 190      public  variant_masters_chr_17
# 191      public  variant_masters_chr_17
# 192      public  variant_masters_chr_18
# 193      public  variant_masters_chr_18
# 194      public  variant_masters_chr_19
# 195      public  variant_masters_chr_19
# 196      public   variant_masters_chr_2
# 197      public   variant_masters_chr_2
# 198      public  variant_masters_chr_20
# 199      public  variant_masters_chr_20
# 200      public  variant_masters_chr_21
# 201      public  variant_masters_chr_21
#
#                                             index_name  index_size  idx_scan
# 1    variant_masters_chr_24_chromosome_position_sta...       47 MB    776847
# 2                          variant_masters_chr_24_pkey       23 MB         0
# 174  variant_masters_chr_1_chromosome_position_star...  8192 bytes         3
# 175                         variant_masters_chr_1_pkey  8192 bytes         0
# 176  variant_masters_chr_10_chromosome_position_sta...  8192 bytes         1
# 177                        variant_masters_chr_10_pkey  8192 bytes         0
# 178  variant_masters_chr_11_chromosome_position_sta...  8192 bytes         1
# 179                        variant_masters_chr_11_pkey  8192 bytes         0
# 180  variant_masters_chr_12_chromosome_position_sta...  8192 bytes         1
# 181                        variant_masters_chr_12_pkey  8192 bytes         0
# 182  variant_masters_chr_13_chromosome_position_sta...  8192 bytes         1
# 183                        variant_masters_chr_13_pkey  8192 bytes         0
# 184  variant_masters_chr_14_chromosome_position_sta...  8192 bytes         1
# 185                        variant_masters_chr_14_pkey  8192 bytes         0
# 186  variant_masters_chr_15_chromosome_position_sta...  8192 bytes         1
# 187                        variant_masters_chr_15_pkey  8192 bytes         0
# 188  variant_masters_chr_16_chromosome_position_sta...  8192 bytes         1
# 189                        variant_masters_chr_16_pkey  8192 bytes         0
# 190  variant_masters_chr_17_chromosome_position_sta...  8192 bytes         1
# 191                        variant_masters_chr_17_pkey  8192 bytes         0
# 192  variant_masters_chr_18_chromosome_position_sta...  8192 bytes         1
# 193                        variant_masters_chr_18_pkey  8192 bytes         0
# 194  variant_masters_chr_19_chromosome_position_sta...  8192 bytes         1
# 195                        variant_masters_chr_19_pkey  8192 bytes         0
# 196  variant_masters_chr_2_chromosome_position_star...  8192 bytes         1
# 197                         variant_masters_chr_2_pkey  8192 bytes         0
# 198  variant_masters_chr_20_chromosome_position_sta...  8192 bytes         1
# 199                        variant_masters_chr_20_pkey  8192 bytes         0
# 200  variant_masters_chr_21_chromosome_position_sta...  8192 bytes         1
# 201                        variant_masters_chr_21_pkey  8192 bytes         0
