# %% [markdown]
# # 🧬 Example Report: Genes to SNPs
# This notebook demonstrates how to run the Gene → SNP report using Biofilter3R.
# It shows how to:
# - Check database connection and schema version
# - List available reports
# - View report documentation
# - Run the report using hardcoded gene lists
# - Run the report from a file-based list

# %% [markdown]
# ### 📦 Step 1: Import Biofilter and connect to the database

# %%
from biofilter import Biofilter

# %%
# Replace with the appropriate connection string for your environment
db_uri = "postgresql+psycopg2://bioadmin:bioadmin@localhost/biofilter"

# Instance of Biofilter
bf = Biofilter(db_uri)

# %%
result = bf.report.run_example_report("report_gene_to_snp")
result.head(10)

# %% [markdown]
# ### 🔍 Step 2: Confirm database schema version (optional)

# %%
print("Current Biofilter Schema Version:", bf.metadata.schema_version)
# Out:
# Current Biofilter Schema Version: 3.1.0

# %% [markdown]
# ### 📃 Step 3: Explore available reports (optional)

# %%
# List all registered reports with descriptions
bf.report.list_reports()
# Out:
# 📄 Available Reports:
# =====================
#
# 1. entity_filter:
#    Validates input list of entity names and returns all matching entities, including conflict and status flags.
#
# 2. qry_etl_status:
#    Summarizes the ETL status for each data source
#
# 3. gene_to_snp:
#    Given a list of genes, returns gene metadata and associated variants (SNPs) with positional and allelic info.
#
# 4. qry_template:
#    Describe what this report does here
# True

# %%
# Show detailed explanation for the Gene-to-SNP report
bf.report.explain("report_gene_to_snp")
# Out:
# 🧬 GENE → SNP Report
# ====================
#
#     This report takes as input a list of genes — accepted formats include:
#     - HGNC symbols (e.g., `TP53`)
#     - HGNC IDs (e.g., `HGNC:11998`)
#     - Entrez IDs (e.g., `7157`)
#     - Ensembl IDs (e.g., `ENSG00000141510`)
#     - Any other symbols
#     - Any other Names or Alias
#
#     It returns:
#     - ✅  Gene metadata (ID, symbol, alias type/source, conflict status)
#     - 🧬  Associated SNPs (from dbSNP)
#     - 📍  Genomic location (chr/start/end/accession)
#     - 🧬  Alleles (ref/alt) and quality
#     - ⚠️  Notes for duplicates or missing variants
#
#
# 🧪 EXAMPLE USAGE
# ================
#
#     > result = bf.report.run_report(
#         "report_gene_to_snp",
#         assembly='38',
#         input_data=["TXLNGY", "HGNC:18473", "246126", "ENSG00000131002", "HGNC:5"]
#         )
#
#
#     If you need run a Example Report:
#         > result = bf.report.run_example_report("report_gene_to_snp")
#
#
#     This returns a Pandas DataFrame with columns:
#         > print(result)
#         Index,Input Gene,HGNC Symbol,Matched Name,Alias Type,Alias Source,Gene ID,Variant ID,Variant Type,Chr,Start,End,Ref Allele,Alt Allele,Accession,Assembly,Quality,Note
#         0,246126,TXLNGY,246126,code,ENTREZ,38610,rs3900,SNV,Y,19568371.0,19568371.0,["G"]",["C"]",NC_000024.10,GRCh38.p14,8.9,
#         ...
#         3233,TXLNGY,TXLNGY,TXLNGY,symbol,HGNC,38610,,,,,,,,,,,Duplicate entity_id: mapped to same gene as another input

# %% [markdown]
# ### ▶️ Step 4: Run the example report (predefined inputs inside the report class)

# %%
result = bf.report.run_example_report("report_gene_to_snp")

# View result
result.head(10)
# Out:
#   Input Gene HGNC Symbol Matched Name Alias Type Alias Source  Gene ID  \
# 0     246126      TXLNGY       246126       code       ENTREZ    38610
# 1     246126      TXLNGY       246126       code       ENTREZ    38610
# 2     246126      TXLNGY       246126       code       ENTREZ    38610
# 3     246126      TXLNGY       246126       code       ENTREZ    38610
# 4     246126      TXLNGY       246126       code       ENTREZ    38610
# 5     246126      TXLNGY       246126       code       ENTREZ    38610
# 6     246126      TXLNGY       246126       code       ENTREZ    38610
# 7     246126      TXLNGY       246126       code       ENTREZ    38610
# 8     246126      TXLNGY       246126       code       ENTREZ    38610
# 9     246126      TXLNGY       246126       code       ENTREZ    38610
#
#   Variant ID Variant Type Chr       Start         End Ref Allele  Alt Allele  \
# 0     rs3900          SNV   Y  19568371.0  19568371.0      ["G"]       ["C"]
# 1     rs3902          SNV   Y  19568761.0  19568761.0      ["A"]       ["G"]
# 2     rs3908       DELINS   Y  19571282.0  19571282.0   ["GGGG"]     ["GGG"]
# 3     rs3909       DELINS   Y  19571277.0  19571278.0      ["A"]      ["AA"]
# 4     rs3910          SNV   Y  19571345.0  19571345.0      ["T"]       ["A"]
# 5     rs3911          SNV   Y  19571568.0  19571568.0      ["A"]       ["G"]
# 6     rs3912          SNV   Y  19570453.0  19570453.0      ["A"]       ["T"]
# 7  rs1058414          SNV   Y  19590151.0  19590151.0      ["G"]       ["A"]
# 8  rs1179186          SNV   Y  19583386.0  19583386.0      ["C"]       ["A"]
# 9  rs1179187          SNV   Y  19582208.0  19582208.0      ["C"]  ["A", "G"]
#
#       Accession    Assembly  Quality  Note
# 0  NC_000024.10  GRCh38.p14      8.9  None
# 1  NC_000024.10  GRCh38.p14      8.3  None
# 2  NC_000024.10  GRCh38.p14      8.1  None
# 3  NC_000024.10  GRCh38.p14      7.5  None
# 4  NC_000024.10  GRCh38.p14      7.5  None
# 5  NC_000024.10  GRCh38.p14      7.8  None
# 6  NC_000024.10  GRCh38.p14      7.5  None
# 7  NC_000024.10  GRCh38.p14      7.5  None
# 8  NC_000024.10  GRCh38.p14      6.5  None
# 9  NC_000024.10  GRCh38.p14      7.5  None

# %% [markdown]
# ### 🧪 Step 5: Run the report with a custom gene list (inline)

# %%
custom_gene_list = [
    "TXLNGY",             # Symbol
    "HGNC:18473",         # HGNC ID
    "246126",             # Entrez ID
    "ENSG00000131002",    # Ensembl ID
    "HGNC:5"              # Another HGNC ID
]

result2 = bf.report.run_report(
    "report_gene_to_snp",
    assembly='GRC38',
    input_data=custom_gene_list,
)

# Preview the result
result2
# Out:
#            Input Gene HGNC Symbol     Matched Name Alias Type Alias Source  \
# 0              246126      TXLNGY           246126       code       ENTREZ
# 1              246126      TXLNGY           246126       code       ENTREZ
# 2              246126      TXLNGY           246126       code       ENTREZ
# 3              246126      TXLNGY           246126       code       ENTREZ
# 4              246126      TXLNGY           246126       code       ENTREZ
# ...               ...         ...              ...        ...          ...
# 3229           246126      TXLNGY           246126       code       ENTREZ
# 3230           HGNC:5        A1BG           HGNC:5       code         HGNC
# 3231  ENSG00000131002      TXLNGY  ENSG00000131002       code      ENSEMBL
# 3232       HGNC:18473      TXLNGY       HGNC:18473       code         HGNC
# 3233           TXLNGY      TXLNGY           TXLNGY     symbol         HGNC
#
#       Gene ID    Variant ID Variant Type  Chr       Start         End  \
# 0       38610        rs3900          SNV    Y  19568371.0  19568371.0
# 1       38610        rs3902          SNV    Y  19568761.0  19568761.0
# 2       38610        rs3908       DELINS    Y  19571282.0  19571282.0
# 3       38610        rs3909       DELINS    Y  19571277.0  19571278.0
# 4       38610        rs3910          SNV    Y  19571345.0  19571345.0
# ...       ...           ...          ...  ...         ...         ...
# 3229    38610  rs2045149522       DELINS    Y  19607647.0  19607647.0
# 3230        1           NaN          NaN  NaN         NaN         NaN
# 3231    38610           NaN          NaN  NaN         NaN         NaN
# 3232    38610           NaN          NaN  NaN         NaN         NaN
# 3233    38610           NaN          NaN  NaN         NaN         NaN
#
#      Ref Allele Alt Allele     Accession    Assembly  Quality  \
# 0         ["G"]      ["C"]  NC_000024.10  GRCh38.p14      8.9
# 1         ["A"]      ["G"]  NC_000024.10  GRCh38.p14      8.3
# 2      ["GGGG"]    ["GGG"]  NC_000024.10  GRCh38.p14      8.1
# 3         ["A"]     ["AA"]  NC_000024.10  GRCh38.p14      7.5
# 4         ["T"]      ["A"]  NC_000024.10  GRCh38.p14      7.5
# ...         ...        ...           ...         ...      ...
# 3229   ["ATAT"]     ["AT"]  NC_000024.10  GRCh38.p14      7.5
# 3230        NaN        NaN           NaN         NaN      NaN
# 3231        NaN        NaN           NaN         NaN      NaN
# 3232        NaN        NaN           NaN         NaN      NaN
# 3233        NaN        NaN           NaN         NaN      NaN
#
#                                                    Note
# 0                                                  None
# 1                                                  None
# 2                                                  None
# 3                                                  None
# 4                                                  None
# ...                                                 ...
# 3229                                               None
# 3230                        No variants found in system
# 3231  Duplicate entity_id: mapped to same gene as an...
# 3232  Duplicate entity_id: mapped to same gene as an...
# 3233  Duplicate entity_id: mapped to same gene as an...
#
# [3234 rows x 17 columns]

# %% [markdown]
# ### 📂 Step 6: Run the report using a gene list from a local file

# %%
# File must contain one gene per line (symbol, ID, or alias)
result3 = bf.report.run_report(
    "report_gene_to_snp",
    input_data="/home/bioadmin/biofilter/notebooks/example_reports/gene_list.txt"
)

# Preview result
print(len(result3))
# Out:
# 3232
