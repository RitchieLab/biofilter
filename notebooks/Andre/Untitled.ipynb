# %%
# !which python
# Out:
# /home/alrico/.conda/envs/biofilter-jupyter/bin/python

# %%
# !python --version
# Out:
# Python 3.11.11

# %%
import biofilter
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 import biofilter
#
# ModuleNotFoundError: No module named 'biofilter'

# %%
import sys
sys.path.append("/project/ritchie/software/biofilter3R")

# %%
import biofilter
