# %%
from biofilter import Biofilter
import biofilter.db.models as models

# %%
db_uri = "sqlite:///dev_biofilter.db"

# %%
bf = Biofilter(db_uri)

# %%
s = bf.db.get_session()

# %%
genes = s.query(models.Gene).limit(5).all()

# %%
genes
# Out:
# [<Gene(hgnc_id=HGNC:5, entity_id=2)>,
#  <Gene(hgnc_id=HGNC:37133, entity_id=3)>,
#  <Gene(hgnc_id=HGNC:24086, entity_id=4)>,
#  <Gene(hgnc_id=HGNC:7, entity_id=5)>,
#  <Gene(hgnc_id=HGNC:27057, entity_id=6)>]
